# %%
#Importation des librairies nécessaires 
import pandas as pd 
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#Chargement de notre dataset en tant que DataFrame
df = pd.read_csv('/Users/come/Desktop/ENSAE/hackathon_responsible_ai_ekimetrics_ensae/stackoverflow_full.csv')
df
# Out:
#        Unnamed: 0  Age Accessibility        EdLevel  Employment     Gender  \
# 0               0  <35            No         Master           1        Man
# 1               1  <35            No  Undergraduate           1        Man
# 2               2  <35            No         Master           1        Man
# 3               3  <35            No  Undergraduate           1        Man
# 4               4  >35            No            PhD           0        Man
# ...           ...  ...           ...            ...         ...        ...
# 73457       73457  <35            No  Undergraduate           1        Man
# 73458       73458  >35            No  Undergraduate           1        Man
# 73459       73459  <35            No  Undergraduate           1        Man
# 73460       73460  <35           Yes  Undergraduate           1        Man
# 73461       73461  <35            No         Master           1  NonBinary
#
#       MentalHealth MainBranch  YearsCode  YearsCodePro  \
# ...

# %%
#Nombre d'observations
nb_obs = df.shape[0]
nb_obs
# Out:
# 73462

# %%
#Existence de valeurs manquantes 
miss_val = df.isna().any().any()
miss_val
# Out:
# True

# %%
#Nombre de valeurs manquantes par colonne 
miss_val_col = df.isna().sum()
miss_val_col
# Out:
# Unnamed: 0         0
# Age                0
# Accessibility      0
# EdLevel            0
# Employment         0
# Gender             0
# MentalHealth       0
# MainBranch         0
# YearsCode          0
# YearsCodePro       0
# Country            0
# PreviousSalary     0
# HaveWorkedWith    63
# ComputerSkills     0
# Employed           0
# dtype: int64
